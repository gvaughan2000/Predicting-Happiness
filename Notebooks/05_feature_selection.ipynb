# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from numpy import where
import matplotlib.pyplot as plt

import sklearn as sk
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

from sklearn import metrics
import seaborn as sns
from sklearn.inspection import permutation_importance
from sklearn.ensemble import GradientBoostingClassifier
from pycm import *
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import tree
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from collections import Counter
import xgboost as xgb
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from boruta import BorutaPy
import ppscore as pps

# %% [markdown]
# # Feature Selection

# %%
X_test = pd.read_excel(f'../processed_data/outliers_removed/imputed/knn/x_test.xlsx')
X_train = pd.read_excel(f'../processed_data/outliers_removed/imputed/knn/x_train.xlsx')
y_train = pd.read_excel(f'../processed_data/outliers_removed/imputed/knn/y_train.xlsx').values.ravel()
y_test = pd.read_excel(f'../processed_data/outliers_removed/imputed/knn/y_test.xlsx').values.ravel()

# %%
X_test.columns
# Out:
# Index(['Year', 'suicide_rates', 'crimes', 'population', 'population_density',
#        'unemployment', 'mean_income_support', 'n_is_claimants', 'house_sales',
#        'bankruptcy', 'processing', 'productivity', 'road_casualties', 'ofsted',
#        'infant_mortality', 'childhood_tooth_decay', 'gp_access',
#        'dental_access', 'Core City', 'Other City', 'Large Town', 'Medium Town',
#        'Small Town', 'Village or smaller', 'gardens_perc',
#        'income_support_rate', 'house_sales_pp', 'bankruptcy_pp',
#        'no_rainy_days', 'inflation', 'previous_period_happiness_change',
#        'Year_no_outliers', 'suicide_rates_no_outliers', 'crimes_no_outliers',
#        'population_no_outliers', 'population_density_no_outliers',
#        'unemployment_no_outliers', 'mean_income_support_no_outliers',
#        'n_is_claimants_no_outliers', 'house_sales_no_outliers',
#        'bankruptcy_no_outliers', 'processing_no_outliers',
#        'productivity_no_outliers', 'road_casualties_no_outliers',
#        'ofsted_no_outliers', 'infant_mortality_no_outliers',
#        'childhood_tooth_decay_no_outliers', 'gp_access_no_outliers',
#        'dental_access_no_outliers', 'Core City_no_outliers',
#        'Other City_no_outliers', 'Large Town_no_outliers',
#        'Medium Town_no_outliers', 'Small Town_no_outliers',
#        'Village or smaller_no_outliers', 'gardens_perc_no_outliers',
#        'income_support_rate_no_outliers', 'house_sales_pp_no_outliers',
#        'bankruptcy_pp_no_outliers', 'no_rainy_days_no_outliers',
#        'inflation_no_outliers',
#        'previous_period_happiness_change_no_outliers'],
#       dtype='object')

# %% [markdown]
# # Barouta

# %%
# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels


def run_barouta(model, X_test, y_test):
    # define Boruta feature selection method
    feat_selector = BorutaPy(model, n_estimators='auto', verbose=2, random_state=42)

    # find all relevant features - 5 features should be selected
    feat_selector.fit(X_test.values, y_test)

    # call transform() on X to filter it down to selected features
    X_filtered = feat_selector.transform(X_test.values)

    # zip my names, ranks, and decisions in a single iterable
    feature_ranks = list(zip(X_test.columns, 
                             feat_selector.ranking_, 
                             feat_selector.support_))

    display(feature_ranks)
    feature_ranks_dict = {}

    for i in feature_ranks:
        name, rank, valid = i
        feature_ranks_dict[name] = rank

    return feature_ranks_dict

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
barouta_rf_dict = run_barouta(rf, X_test, y_test)
barouta_rf_dict
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	62
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	9
# Rejected: 	53
# Iteration: 	9 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	10 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	11 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	12 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	13 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	14 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	15 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	16 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	17 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	18 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	19 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	20 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	21 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	22 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	23 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	24 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	25 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	26 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	27 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	28 / 100
# Confirmed: 	2
# Tentative: 	7
# Rejected: 	53
# Iteration: 	29 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	54
# Iteration: 	30 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	54
# Iteration: 	31 / 100
# Confirmed: 	2
# Tentative: 	6
# Rejected: 	54
# Iteration: 	32 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	33 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	34 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	35 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	36 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	37 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	38 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	39 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	40 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	41 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	42 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	43 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	44 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	45 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	46 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	47 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	48 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	49 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	50 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	51 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	52 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	53 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	54 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	55 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	56 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	57 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	58 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	59 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	60 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	61 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	62 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	63 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	64 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	65 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	66 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	67 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	68 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	69 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	70 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	71 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	72 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	73 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	74 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	75 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	76 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	77 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	78 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	79 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	80 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	81 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	82 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	83 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	84 / 100
# Confirmed: 	3
# Tentative: 	5
# Rejected: 	54
# Iteration: 	85 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	86 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	87 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	88 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	89 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	90 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	91 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	92 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	93 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	94 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	95 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	96 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	97 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	98 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
# Iteration: 	99 / 100
# Confirmed: 	4
# Tentative: 	4
# Rejected: 	54
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	4
# Tentative: 	3
# Rejected: 	54
# [('Year', 2, False),
#  ('suicide_rates', 51, False),
#  ('crimes', 8, False),
#  ('population', 42, False),
#  ('population_density', 30, False),
#  ('unemployment', 33, False),
#  ('mean_income_support', 3, False),
#  ('n_is_claimants', 21, False),
#  ('house_sales', 10, False),
#  ('bankruptcy', 41, False),
#  ('processing', 17, False),
#  ('productivity', 7, False),
#  ('road_casualties', 16, False),
#  ('ofsted', 37, False),
#  ('infant_mortality', 32, False),
#  ('childhood_tooth_decay', 1, True),
#  ('gp_access', 25, False),
#  ('dental_access', 4, False),
#  ('Core City', 55, False),
#  ('Other City', 56, False),
#  ('Large Town', 52, False),
#  ('Medium Town', 54, False),
#  ('Small Town', 53, False),
#  ('Village or smaller', 28, False),
#  ('gardens_perc', 13, False),
#  ('income_support_rate', 39, False),
#  ('house_sales_pp', 28, False),
#  ('bankruptcy_pp', 36, False),
#  ('no_rainy_days', 46, False),
#  ('inflation', 48, False),
#  ('previous_period_happiness_change', 1, True),
#  ('Year_no_outliers', 1, True),
#  ('suicide_rates_no_outliers', 50, False),
#  ('crimes_no_outliers', 12, False),
#  ('population_no_outliers', 43, False),
#  ('population_density_no_outliers', 32, False),
#  ('unemployment_no_outliers', 46, False),
#  ('mean_income_support_no_outliers', 3, False),
#  ('n_is_claimants_no_outliers', 24, False),
#  ('house_sales_no_outliers', 5, False),
#  ('bankruptcy_no_outliers', 44, False),
#  ('processing_no_outliers', 11, False),
#  ('productivity_no_outliers', 19, False),
#  ('road_casualties_no_outliers', 15, False),
#  ('ofsted_no_outliers', 35, False),
#  ('infant_mortality_no_outliers', 48, False),
#  ('childhood_tooth_decay_no_outliers', 2, False),
#  ('gp_access_no_outliers', 10, False),
#  ('dental_access_no_outliers', 2, False),
#  ('Core City_no_outliers', 15, False),
#  ('Other City_no_outliers', 38, False),
#  ('Large Town_no_outliers', 19, False),
#  ('Medium Town_no_outliers', 49, False),
#  ('Small Town_no_outliers', 29, False),
#  ('Village or smaller_no_outliers', 26, False),
#  ('gardens_perc_no_outliers', 23, False),
#  ('income_support_rate_no_outliers', 35, False),
#  ('house_sales_pp_no_outliers', 19, False),
#  ('bankruptcy_pp_no_outliers', 22, False),
#  ('no_rainy_days_no_outliers', 40, False),
#  ('inflation_no_outliers', 6, False),
#  ('previous_period_happiness_change_no_outliers', 1, True)]
# {'Year': 2,
#  'suicide_rates': 51,
#  'crimes': 8,
#  'population': 42,
#  'population_density': 30,
#  'unemployment': 33,
#  'mean_income_support': 3,
#  'n_is_claimants': 21,
#  'house_sales': 10,
#  'bankruptcy': 41,
#  'processing': 17,
#  'productivity': 7,
#  'road_casualties': 16,
#  'ofsted': 37,
#  'infant_mortality': 32,
#  'childhood_tooth_decay': 1,
#  'gp_access': 25,
#  'dental_access': 4,
#  'Core City': 55,
#  'Other City': 56,
#  'Large Town': 52,
#  'Medium Town': 54,
#  'Small Town': 53,
#  'Village or smaller': 28,
#  'gardens_perc': 13,
#  'income_support_rate': 39,
#  'house_sales_pp': 28,
#  'bankruptcy_pp': 36,
#  'no_rainy_days': 46,
#  'inflation': 48,
#  'previous_period_happiness_change': 1,
#  'Year_no_outliers': 1,
#  'suicide_rates_no_outliers': 50,
#  'crimes_no_outliers': 12,
#  'population_no_outliers': 43,
#  'population_density_no_outliers': 32,
#  'unemployment_no_outliers': 46,
#  'mean_income_support_no_outliers': 3,
#  'n_is_claimants_no_outliers': 24,
#  'house_sales_no_outliers': 5,
#  'bankruptcy_no_outliers': 44,
#  'processing_no_outliers': 11,
#  'productivity_no_outliers': 19,
#  'road_casualties_no_outliers': 15,
#  'ofsted_no_outliers': 35,
#  'infant_mortality_no_outliers': 48,
#  'childhood_tooth_decay_no_outliers': 2,
#  'gp_access_no_outliers': 10,
#  'dental_access_no_outliers': 2,
#  'Core City_no_outliers': 15,
#  'Other City_no_outliers': 38,
#  'Large Town_no_outliers': 19,
#  'Medium Town_no_outliers': 49,
#  'Small Town_no_outliers': 29,
#  'Village or smaller_no_outliers': 26,
#  'gardens_perc_no_outliers': 23,
#  'income_support_rate_no_outliers': 35,
#  'house_sales_pp_no_outliers': 19,
#  'bankruptcy_pp_no_outliers': 22,
#  'no_rainy_days_no_outliers': 40,
#  'inflation_no_outliers': 6,
#  'previous_period_happiness_change_no_outliers': 1}

# %% [markdown]
# # Sci Kit Learn

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
rf.fit(X_train, y_train)

scikitlearn_features = pd.DataFrame({'feature_importance': rf.feature_importances_}, index=X_train.columns)
scikitlearn_features['SciKitLearn: RandomForest'] = scikitlearn_features['feature_importance'].rank(method='dense', ascending=False)

scikitlearn_features = scikitlearn_features.drop('feature_importance', axis=1)
scikitlearn_features
# Out:
#                                               SciKitLearn: RandomForest
# Year                                                                3.0
# suicide_rates                                                      53.0
# crimes                                                              9.0
# population                                                         47.0
# population_density                                                 59.0
# ...                                                                 ...
# house_sales_pp_no_outliers                                         31.0
# bankruptcy_pp_no_outliers                                          43.0
# no_rainy_days_no_outliers                                          18.0
# inflation_no_outliers                                              27.0
# previous_period_happiness_change_no_outliers                        1.0
#
# [62 rows x 1 columns]

# %% [markdown]
# # Predictive Power Score

# %%
df = X_train.copy()
df['mean_happiness'] = y_train

pps_df = pps.predictors(df, "mean_happiness")
pps_df['pps_rank'] = pps_df['ppscore'].rank(method='dense', ascending=False)

# %% [markdown]
# # Correlation

# %%
corr_dict = {}

for col in X_train.columns:
    corr = np.corrcoef(X_train[col], y_train)[0][1]
    corr_dict[col] = corr

corr_dict = {key: rank for rank, key in enumerate(sorted(corr_dict, key=corr_dict.get), 1)}
corr_dict
# Out:
# {'previous_period_happiness_change': 1,
#  'previous_period_happiness_change_no_outliers': 2,
#  'Year_no_outliers': 3,
#  'Year': 4,
#  'mean_income_support_no_outliers': 5,
#  'mean_income_support': 6,
#  'unemployment_no_outliers': 7,
#  'unemployment': 8,
#  'no_rainy_days_no_outliers': 9,
#  'no_rainy_days': 10,
#  'bankruptcy_pp': 11,
#  'n_is_claimants': 12,
#  'bankruptcy_pp_no_outliers': 13,
#  'n_is_claimants_no_outliers': 14,
#  'Village or smaller': 15,
#  'Village or smaller_no_outliers': 16,
#  'bankruptcy': 17,
#  'bankruptcy_no_outliers': 18,
#  'Medium Town_no_outliers': 19,
#  'income_support_rate_no_outliers': 20,
#  'Small Town': 21,
#  'productivity': 22,
#  'productivity_no_outliers': 23,
#  'Medium Town': 24,
#  'road_casualties_no_outliers': 25,
#  'gp_access': 26,
#  'income_support_rate': 27,
#  'gp_access_no_outliers': 28,
#  'house_sales_pp': 29,
#  'Small Town_no_outliers': 30,
#  'road_casualties': 31,
#  'house_sales_pp_no_outliers': 32,
#  'Large Town': 33,
#  'Other City': 34,
#  'Large Town_no_outliers': 35,
#  'Core City': 36,
#  'Core City_no_outliers': 37,
#  'population_density_no_outliers': 38,
#  'population_density': 39,
#  'suicide_rates_no_outliers': 40,
#  'gardens_perc_no_outliers': 41,
#  'ofsted': 42,
#  'suicide_rates': 43,
#  'ofsted_no_outliers': 44,
#  'Other City_no_outliers': 45,
#  'infant_mortality_no_outliers': 46,
#  'population_no_outliers': 47,
#  'inflation': 48,
#  'infant_mortality': 49,
#  'gardens_perc': 50,
#  'population': 51,
#  'inflation_no_outliers': 52,
#  'processing': 53,
#  'childhood_tooth_decay_no_outliers': 54,
#  'childhood_tooth_decay': 55,
#  'dental_access': 56,
#  'processing_no_outliers': 57,
#  'dental_access_no_outliers': 58,
#  'house_sales_no_outliers': 59,
#  'house_sales': 60,
#  'crimes_no_outliers': 61,
#  'crimes': 62}

# %% [markdown]
# # Comparison

# %%
feature_comparison_df = pps_df[['x', 'pps_rank']].set_index('x')
feature_comparison_df['Barouta: RandomForest'] = feature_comparison_df.index.map(barouta_rf_dict)

feature_comparison_df['correlation'] = feature_comparison_df.index.map(corr_dict)

feature_comparison_df['average_rank'] = feature_comparison_df.mean(axis=1)
feature_comparison_df = feature_comparison_df.sort_values('average_rank')

feature_comparison_df.head(35)
# Out:
#                                               pps_rank  Barouta: RandomForest  \
# x
# previous_period_happiness_change                   1.0                      1
# previous_period_happiness_change_no_outliers       2.0                      1
# Year                                               4.0                      2
# Year_no_outliers                                   6.0                      1
# mean_income_support_no_outliers                   18.0                      3
# mean_income_support                               18.0                      3
# productivity                                       8.0                      7
# productivity_no_outliers                           7.0                     19
# n_is_claimants                                    18.0                     21
# no_rainy_days_no_outliers                          3.0                     40
# bankruptcy_pp_no_outliers                         18.0                     22
# gp_access_no_outliers                             18.0                     10
# n_is_claimants_no_outliers                        18.0                     24
# road_casualties_no_outliers                       18.0                     15
# unemployment                                      17.0                     33
# Village or smaller_no_outliers                    18.0                     26
# no_rainy_days                                      4.0                     46
# house_sales_pp_no_outliers                        10.0                     19
# Village or smaller                                18.0                     28
# inflation_no_outliers                              5.0                      6
# bankruptcy_pp                                     18.0                     36
# road_casualties                                   18.0                     16
# house_sales_pp                                     9.0                     28
# childhood_tooth_decay_no_outliers                 11.0                      2
# unemployment_no_outliers                          15.0                     46
# gp_access                                         18.0                     25
# Core City_no_outliers                             18.0                     15
# childhood_tooth_decay                             16.0                      1
# Large Town_no_outliers                            18.0                     19
# income_support_rate_no_outliers                   18.0                     35
# dental_access                                     14.0                      4
# bankruptcy                                        18.0                     41
# Small Town_no_outliers                            18.0                     29
# dental_access_no_outliers                         18.0                      2
# bankruptcy_no_outliers                            18.0                     44
#
#                                               correlation  average_rank
# x
# previous_period_happiness_change                        1      1.000000
# previous_period_happiness_change_no_outliers            2      1.666667
# Year                                                    4      3.333333
# Year_no_outliers                                        3      3.333333
# mean_income_support_no_outliers                         5      8.666667
# mean_income_support                                     6      9.000000
# productivity                                           22     12.333333
# productivity_no_outliers                               23     16.333333
# n_is_claimants                                         12     17.000000
# no_rainy_days_no_outliers                               9     17.333333
# bankruptcy_pp_no_outliers                              13     17.666667
# gp_access_no_outliers                                  28     18.666667
# n_is_claimants_no_outliers                             14     18.666667
# road_casualties_no_outliers                            25     19.333333
# unemployment                                            8     19.333333
# Village or smaller_no_outliers                         16     20.000000
# no_rainy_days                                          10     20.000000
# house_sales_pp_no_outliers                             32     20.333333
# Village or smaller                                     15     20.333333
# inflation_no_outliers                                  52     21.000000
# bankruptcy_pp                                          11     21.666667
# road_casualties                                        31     21.666667
# house_sales_pp                                         29     22.000000
# childhood_tooth_decay_no_outliers                      54     22.333333
# unemployment_no_outliers                                7     22.666667
# gp_access                                              26     23.000000
# Core City_no_outliers                                  37     23.333333
# childhood_tooth_decay                                  55     24.000000
# Large Town_no_outliers                                 35     24.000000
# income_support_rate_no_outliers                        20     24.333333
# dental_access                                          56     24.666667
# bankruptcy                                             17     25.333333
# Small Town_no_outliers                                 30     25.666667
# dental_access_no_outliers                              58     26.000000
# bankruptcy_no_outliers                                 18     26.666667

# %%
textfile = open("features.txt", "w")
for element in feature_comparison_df.index:
    textfile.write(element + "\n")
textfile.close()
